# %% [markdown]
# <a href="https://colab.research.google.com/github/Mudith-cloud/NLP-experiments/blob/main/Experiment_8_%20ImplementWordSenseDisambiguation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.wsd import lesk

sentences = [
    ("I went to the bank to deposit money", "bank"),
    ("We sat on the bank of the river", "bank"),
    ("The bat flew out of the cave", "bat"),
    ("He hit the ball with a bat", "bat")
]

for sentence, word in sentences:
    words = sentence.split()
    sense = lesk(words, word)

    print("Sentence:", sentence)
    print("Word:", word)
    print("Sense:", sense)

    if sense:
        print("Definition:", sense.definition())

    print()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Sentence: I went to the bank to deposit money
# Word: bank
# Sense: Synset('savings_bank.n.02')
# Definition: a container (usually with a slot in the top) for keeping money at home
#
# Sentence: We sat on the bank of the river
# Word: bank
# Sense: Synset('bank.v.07')
# Definition: cover with ashes so to control the rate of burning
#
# Sentence: The bat flew out of the cave
# Word: bat
# Sense: Synset('cricket_bat.n.01')
# Definition: the club used in playing cricket
#
# Sentence: He hit the ball with a bat
# Word: bat
# Sense: Synset('bat.v.01')
# Definition: strike with, or as if with a baseball bat
